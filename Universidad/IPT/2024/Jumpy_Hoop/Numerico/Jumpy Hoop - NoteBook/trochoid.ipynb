# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import math
plt.style.reload_library()
plt.style.use(['science','notebook'])
from itertools import combinations
print('done')
# Out:
# done

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.constants import g

# %%
def f(theta, t, v0,R,l, epsilon):
    c = v0**2 / (4*g*R)
    dtheta_dt_2 = (g/R) * (((1 + l + l*epsilon/2)*c) + 2*l*np.sin(theta/2)**2) / (1 + l*np.cos(theta) + l*epsilon/2)
    return np.sqrt(dtheta_dt_2)

# %%
R = 5
v0 = 0.3
l = 4/5
epsilon = 0.1

t = np.linspace(0, 5, 1000)
sol = odeint(f, 0, t, args=(R, v0, l, epsilon)).T

# %%
theta = sol[0]

def trochoid(R, theta, l):
    x = R*(theta + l*np.sin(theta))
    y = R*(1 + l*np.cos(theta))
    return x,y

# %%
plt.plot(t, theta)

# %%
x,y = trochoid(R, theta, l)

plt.plot(x,y)
plt.title('Analytical solution without jumping.')
plt.xlabel('x')
plt.ylim(0,10)
plt.xlim(0,100)
plt.ylabel( 'y')
plt.savefig("Graf_1.png", dpi=500)
plt.grid()

# %%
xp, yp = trochoid(R, np.linspace(0,8*np.pi), 4/5)
plt.plot(xp, yp)
