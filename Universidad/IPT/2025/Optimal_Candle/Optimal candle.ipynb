# %%
ximport pandas as pd

df = pd.read_csv('Candle_2.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df['time'], df['I'], marker='o')
plt.title('Candle 2')
plt.xlabel('Time')
plt.ylabel('Illuminance (lx)')
plt.grid()
plt.show()

# %%
import pandas as pd

df3 = pd.read_csv('Candle_3.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df3['time'], df3['I'], marker='o')
plt.title('Candle 3')
plt.xlabel('Time')
plt.ylabel('Illuminance (lx)')
plt.grid()
plt.show()

# %%
import pandas as pd

df4 = pd.read_csv('Candle_4.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df4['time'], df4['I'], marker='o')
plt.title('Candle 4')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
plt.xlim(0,600)
plt.grid()
plt.show()

# %%
import pandas as pd

df5 = pd.read_csv('Candle_5.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df5['time'], df5['I'], marker='o')
plt.title('Candle 5')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
plt.xlim(10,600)
plt.grid()
plt.show()

# %%
plt.plot(df['time'], df['I'], marker='o')
plt.plot(df3['time'], df3['I'], marker='o')
plt.plot(df4['time'], df4['I'], marker='o')
plt.plot(df5['time'], df5['I'], marker='o')

plt.title('Candle 5')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
plt.xlim(100,600)
plt.ylim(-1,80)

#plt.legend()
plt.grid()
plt.show()

# %%
import pandas as pd

df = pd.read_csv('Candle_1_1.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df['time'], df['I'], marker='o')
plt.title('Candle 1')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
plt.xlim(10,600)
plt.grid()
plt.show()

# %%
import pandas as pd

df2 = pd.read_csv('Candle_1_2.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df2['time'], df2['I'], marker='o')
plt.title('Candle 2')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
plt.xlim(10,800)
plt.grid()
plt.show()

# %%
import pandas as pd

df3 = pd.read_csv('Candle_1_3.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df3['time'], df3['I'], marker='o')
plt.title('Candle 3')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
#plt.xlim(10,800)
plt.grid()
plt.show()

# %%
import pandas as pd

df4 = pd.read_csv('Candle_1_4.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df4['time'], df4['I'], marker='o')
plt.title('Candle 4')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
#plt.xlim(10,650)
plt.grid()
plt.show()

# %%
import pandas as pd

df5 = pd.read_csv('Candle_1_5.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df5['time'], df5['I'], marker='o')
plt.title('Candle 5')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
plt.xlim(10,600)
plt.grid()
plt.show()

# %%
import pandas as pd

df6 = pd.read_csv('Candle_1_6.csv')


import matplotlib.pyplot as plt

# Suponiendo que tienes dos columnas 'x' y 'y' en tu CSV
plt.plot(df6['time'], df6['I'], marker='o')
plt.title('Candle 6')
plt.xlabel('Time (s)')
plt.ylabel('Illuminance (lx)')
plt.xlim(10,600)
plt.grid()
plt.show()
