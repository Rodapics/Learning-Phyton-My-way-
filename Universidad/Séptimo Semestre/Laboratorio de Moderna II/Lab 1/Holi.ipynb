# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Gráfico de la función seno', bbox={'facecolor':'gray', 'alpha':0.5, 'pad':10})
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

fig, ax = plt.subplots()
line, = ax.plot(x, y)
line_box = mpatches.Rectangle((3, -1), 4, 2, linewidth=1, edgecolor='red', facecolor='none')
ax.add_patch(line_box)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label='Seno')
plt.plot(x, y2, label='Coseno')
plt.legend()


plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(8,8))


plt.plot(x, y, "bo", label='Datos') 
plt.title('Partículas detectadas por segundo en función de la distancia', fontsize = 20)
plt.legend(loc ='upper right')
plt.grid(True)
plt.xlabel('Distancia ($10^{-2}m$)', fontsize = 20)
plt.ylabel(r'$\frac{N}{s}$', fontsize = 30)

plt.show()
