# %%
#Librerias
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scienceplots

#Diseño de Graficas
plt.style.reload_library()
plt.style.use(['science','notebook']) 

print('done')
# Out:
# done

# %% [markdown]
# Oxigeno

# %%
m_e = 15.99

v=np.linspace(0,25)
E = 1/2*m_e*v**2

T2 = 90
k = 1.380649e-23
N = 6.02e+23
dn =2*np.pi*(1/(np.pi*T))**(3/2)*E*np.e**(-(E)/(T))

# %%
m_e = 15.99
v=np.linspace(0,20)
E = 1/2*m_e*v**2

T2 = 900
k = 1.380649e-23
N = 6.02e+23
dn2 =2*np.pi*(1/(np.pi*T2))**(3/2)*E*np.e**(-(E)/(T2))

# %%
plt.plot(E,dn, label ='T=90 K')
plt.plot(E,dn2, label ='T=900 K')

plt.title('Distribución de Energética de MBP para una molecula diatomica de Oxigeno.',  fontsize = 20)
plt.ylabel('Densidad de Energía $(dn_{\epsilon})/(d\epsilon) $', fontsize = 20)
plt.xlabel('Energía $ (\epsilon)/(K_{BT})$', fontsize = 20)
plt.legend()
plt.grid()
plt.savefig('grafica1.png', dpi=300) 
plt.show()

# %% [markdown]
# Nitrogeno

# %%
m_n = 14

v=np.linspace(0,20)

En = 1/2*m_n*v**2

T = 90
k = 1.380649e-23
N = 6.02e+23
dnn =2*np.pi*(1/(np.pi*T))**(3/2)*En*np.e**(-(En)/(T))

# %%
m_n = 14

v=np.linspace(0,20)

En = 1/2*m_n*v**2

T2 = 900
k = 1.380649e-23
N = 6.02e+23
dnn2 =2*np.pi*(1/(np.pi*T2))**(3/2)*En*np.e**(-(En)/(T2))

# %%
plt.plot(E,dnn, label ='T=90 K')
plt.plot(E,dnn2, label ='T=900 K')

plt.title('Distribución de Energética de MBP para una molecula diatomica de Nitrogeno.',  fontsize = 20)
plt.ylabel('Densidad de Energía $(dn_{\epsilon})/(d\epsilon) $', fontsize = 20)
plt.xlabel('Energía $ (\epsilon)/(K_{BT})$', fontsize = 20)
plt.legend()
plt.grid()
plt.savefig('grafica2.png', dpi=300) 
plt.show()

# %% [markdown]
# Grafica conjunta

# %%
plt.plot(E,dnn, label ='T=90 K - Nitrogeno')
plt.plot(E,dnn2, label ='T=900 K - Nitrogeno')
plt.plot(E,dn, label ='T=90 K - Oxigeno')
plt.plot(E,dn2, label ='T=900 K - Oxigeno')


plt.title('Distribución de Energética de MBP para una molecula diatomica.',  fontsize = 20)
plt.ylabel('Densidad de Energía $(dn_{\epsilon})/(d\epsilon) $', fontsize = 20)
plt.xlabel('Energía $ (\epsilon)/(K_{BT})$', fontsize = 20)
plt.legend()

plt.grid()
plt.savefig('grafica3.png', dpi=300) 
plt.show()
