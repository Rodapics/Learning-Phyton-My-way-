# %%
#Librerias
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scienceplots

#Diseño de Graficas
plt.style.reload_library()
plt.style.use(['science','notebook']) 

print('done')
# Out:
# done

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros de la molécula de oxígeno
m = 5.31e-26  # Masa de una molécula de oxígeno en kg
T = 300       # Temperatura en Kelvin

# Función de distribución de velocidades de Maxwell-Boltzmann
def maxwell_boltzmann(v, m, T):
    return (np.sqrt(2 / np.pi) * np.power((m / (2 * np.pi * T)) , 3 / 2) * np.exp(-m * v**2 / (2 * T)))

# Rango de velocidades
v = np.linspace(0, 3000, 1000)  # Valores de velocidad en m/s

# Calcula la distribución de velocidades de Maxwell-Boltzmann
f = maxwell_boltzmann(v, m, T)

# Graficar la distribución de velocidades
plt.plot(v, f)
plt.xlabel('Velocidad (m/s)')
plt.ylabel('Distribución de velocidades')
plt.title('Distribución de velocidades de Maxwell-Boltzmann \n para una molécula diatómica de oxígeno a 300 K')
plt.grid(True)
plt.show()
