# %%
import numpy as np

# %% [markdown]
# ##Errores de suma

# %%
#Error de suma, resultados diferentes para la misma operación
import sympy as sp

a = -1.95E16
b = 1.95E16
print("a=",a)
print("b=",b)
c = (a+b)+1.0

d = a+(b+1.0)

print("c=",c)
#La propiedad asociativa no se cumple en el computador.
print("d=",d)

#Con 15 funciona, en 16 falla. Asignación de números.
# Out:
# a= -1.95e+16
# b= 1.95e+16
# c= 1.0
# d= 0.0

# %% [markdown]
# ## Operaciones de máquina
# Y otras cosas raras que ponía este señor

# %%
0.078125-0.0625
# Out:
# 0.015625

# %%
0.093750-0.078125
# Out:
# 0.015625

# %%
0.125000-0.1093750
# Out:
# 0.015625

# %%
0.156250-0.125
# Out:
# 0.03125

# %% [markdown]
# ## Epsilón de máquina

# %%
#Cálculo del epsilón de máquina
p=0
epsilon = 1
while 1 + epsilon!=1:
  epsilon=epsilon/2
  p=p+1
print(epsilon,p)
# Out:
# 1.1102230246251565e-16 53

# %%
1/(2**53)
# Out:
# 1.1102230246251565e-16

# %%
1/(2**24)
# Out:
# 5.960464477539063e-08

# %% [markdown]
#   Cómo lo haria el profesor

# %%
e=1
p=0

while 1+e!=1:
  e=e/2
  p+=1

print(f"EL epsilón de máquina es {e} y el ciclo se ha repetido {p} veces")

# Lidiar con estos valores, estos errores en cada operación que realiza el computador.
# Out:
# EL epsilón de máquina es 1.1102230246251565e-16 y el ciclo se ha repetido 53 veces

# %% [markdown]
# Hablando de $$\Pi$$

# %%
print(np.pi)
# Out:
# 3.141592653589793
